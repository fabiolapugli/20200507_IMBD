# %% [markdown]
# <a href="https://colab.research.google.com/github/fabiolapugli/20200507_IMBD/blob/master/C%C3%B3pia_de_Aula1_LC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip instal opencv-python
# Out:
# ERROR: unknown command "instal" - maybe you meant "install"

# %%
pip install opencv-python

# %%
import numpy
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %%
imagem = cv2.imread('lena_bw.png')

# %%
type(imagem)
# Out:
# numpy.ndarray

# %%
imagem.shape
# Out:
# (567, 567, 3)

# %%
plt.imshow(imagem)
